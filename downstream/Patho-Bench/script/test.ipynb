# %%
import os
import pandas as pd
from sklearn.model_selection import StratifiedKFold

def convert_csv_to_tsv_auto_label(
    input_folder: str,
    output_folder: str,
    label_col: str = "label",
    slide_id_col: str = "slide_id",
    min_samples_for_5fold: int = 100,
    n_splits: int = 5
):
  

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if not filename=='BRACS_COARSE.csv':
            continue
        if not filename.lower().endswith(".csv"):
            continue
        targe_label_col = filename.split('.')[0].lower()
        csv_path = os.path.join(input_folder, filename)
        df = pd.read_csv(csv_path)
        
        # 检查所需列
        if label_col not in df.columns:
            print(f"[跳过文件] {filename}: 不存在列 '{label_col}'")
            continue
        if slide_id_col not in df.columns:
            print(f"[跳过文件] {filename}: 不存在列 '{slide_id_col}'")
            continue
        label_counts = df[label_col].value_counts()  
        unique_labels = label_counts.index 
        auto_label_dict = { lab: i for i, lab in enumerate(unique_labels) }
        df[label_col] = df[label_col].map(auto_label_dict)
        total_samples = len(df)
        if total_samples < min_samples_for_5fold:
      
            df["fold_0"] = "train"
            print(f"{filename}: 样本量 {total_samples} < {min_samples_for_5fold}, 仅生成 fold_0(train)")
        else:
            X = df.index
            y = df[label_col]
            for fold_idx in range(n_splits):
                df[f"fold_{fold_idx}"] = "train"
            
            skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
            for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X, y)):
                df.loc[val_idx, f"fold_{fold_idx}"] = "test"

            print(f"{filename}: 样本量 {total_samples} >= {min_samples_for_5fold}, 生成 {n_splits} 折交叉验证列")
        
        # 输出为TSV
        tsv_name = filename.rsplit(".", 1)[0] + ".tsv"
        tsv_path = os.path.join(output_folder, tsv_name)
        #rename label column
        df.rename(columns={label_col: targe_label_col}, inplace=True)
        df.to_csv(tsv_path, sep='\t', index=False)
        print(f"=> 已输出TSV文件: {tsv_path}")

if __name__ == "__main__":
    # 使用示例：根据实际需求填写 input_folder 和 output_folder
    input_folder = "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype"
    output_folder = "/home/yuhaowang/project/FMBC/downstream/Patho-Bench/dataset_tsv"

    convert_csv_to_tsv_auto_label(
        input_folder=input_folder,
        output_folder=output_folder,
        label_col="label",         # CSV中表示类别的列
        slide_id_col="slide_id",   # CSV中表示slide ID的列
        min_samples_for_5fold=100, # 小于100 => 只生成fold_0
        n_splits=5                 # 五折
    )
# Out:
# BRACS_COARSE.csv: 样本量 547 >= 100, 生成 5 折交叉验证列
# => 已输出TSV文件: /home/yuhaowang/project/FMBC/downstream/Patho-Bench/dataset_tsv/BRACS_COARSE.tsv

# %%
#validation the tsv dir
import os
#read tsv file
def read_tsv_file(file_path):
    with open(file_path, 'r') as f:
        lines = f.readlines()
    return lines

data_path = '/home/yuhaowang/project/FMBC/downstream/Patho-Bench/dataset_tsv/BRACS_COARSE.tsv'
data = read_tsv_file(data_path)

# %%
# import shutil
# data_dir = '/data4/embedding'
# for dir in os.listdir(data_dir):
#     for model in os.listdir(os.path.join(data_dir, dir)):
#         print(os.path.join(data_dir, dir, model))
#         #if name contrain FMBC, remove dir
#         if 'FMBC' in model:
#             print('remove', os.path.join(data_dir, dir, model))
#             shutil.rmtree(os.path.join(data_dir, dir, model))
# Out:
# /data4/embedding/BreakHis/CONCH
# /data4/embedding/BreakHis/UNI
# /data4/embedding/BreakHis/CHIEF
# /data4/embedding/BreakHis/Virchow
# /data4/embedding/BreakHis/Gigapath_tile
# /data4/embedding/BreakHis/Gigapath
# /data4/embedding/BreakHis/TITAN
# /data4/embedding/private_chunk_test/CONCH
# /data4/embedding/private_chunk_test/UNI
# /data4/embedding/private_chunk_test/Virchow
# /data4/embedding/private_chunk_test/Gigapath_tile
# /data4/embedding/private_chunk_test/Gigapath
# /data4/embedding/private_chunk_test/TITAN
# /data4/embedding/HIST2ST/CONCH
# /data4/embedding/HIST2ST/UNI
# /data4/embedding/HIST2ST/Virchow
# /data4/embedding/HIST2ST/Gigapath_tile
# /data4/embedding/HIST2ST/Gigapath
# /data4/embedding/HIST2ST/TITAN
# /data4/embedding/TUPAC/CONCH
# /data4/embedding/TUPAC/UNI
# /data4/embedding/TUPAC/FMBC
# remove /data4/embedding/TUPAC/FMBC
# /data4/embedding/TUPAC/CHIEF
# /data4/embedding/TUPAC/Virchow
# /data4/embedding/TUPAC/Gigapath_tile
# /data4/embedding/TUPAC/Gigapath
# /data4/embedding/TUPAC/TITAN
# /data4/embedding/private_chunk_3/FMBC
# remove /data4/embedding/private_chunk_3/FMBC
# /data4/embedding/private_chunk_7/FMBC
# remove /data4/embedding/private_chunk_7/FMBC
# /data4/embedding/GEO-GSE243280/CONCH
# /data4/embedding/GEO-GSE243280/UNI
# /data4/embedding/GEO-GSE243280/Virchow
# /data4/embedding/GEO-GSE243280/Gigapath_tile
# /data4/embedding/GEO-GSE243280/TITAN
# /data4/embedding/HE-vs-MPM/CONCH
# /data4/embedding/HE-vs-MPM/UNI
# /data4/embedding/HE-vs-MPM/CHIEF
# /data4/embedding/HE-vs-MPM/Virchow
# /data4/embedding/HE-vs-MPM/Gigapath_tile
# /data4/embedding/HE-vs-MPM/Gigapath
# /data4/embedding/HE-vs-MPM/TITAN
# /data4/embedding/CAMELYON16/CONCH
# /data4/embedding/CAMELYON16/UNI
# /data4/embedding/CAMELYON16/FMBC
# remove /data4/embedding/CAMELYON16/FMBC
# /data4/embedding/CAMELYON16/CHIEF
# /data4/embedding/CAMELYON16/Virchow
# /data4/embedding/CAMELYON16/Gigapath_tile
# /data4/embedding/CAMELYON16/Gigapath
# /data4/embedding/CAMELYON16/TITAN
# /data4/embedding/BRACS/CONCH
# /data4/embedding/BRACS/UNI
# /data4/embedding/BRACS/CHIEF
# /data4/embedding/BRACS/Virchow
# /data4/embedding/BRACS/UNI-2
# /data4/embedding/BRACS/Gigapath_tile
# /data4/embedding/BRACS/Gigapath
# /data4/embedding/BRACS/TITAN
# /data4/embedding/Post-NAT-BRCA/CONCH
# /data4/embedding/Post-NAT-BRCA/UNI
# /data4/embedding/Post-NAT-BRCA/FMBC
# remove /data4/embedding/Post-NAT-BRCA/FMBC
# /data4/embedding/Post-NAT-BRCA/CHIEF
# /data4/embedding/Post-NAT-BRCA/Virchow
# /data4/embedding/Post-NAT-BRCA/Gigapath_tile
# /data4/embedding/Post-NAT-BRCA/Gigapath
# /data4/embedding/Post-NAT-BRCA/TITAN
# /data4/embedding/IMPRESS/CONCH
# /data4/embedding/IMPRESS/UNI
# /data4/embedding/IMPRESS/FMBC
# remove /data4/embedding/IMPRESS/FMBC
# /data4/embedding/IMPRESS/CHIEF
# /data4/embedding/IMPRESS/Virchow
# /data4/embedding/IMPRESS/Gigapath_tile
# /data4/embedding/IMPRESS/Gigapath
# /data4/embedding/IMPRESS/TITAN
# /data4/embedding/TCGA-BRCA/CONCH
# /data4/embedding/TCGA-BRCA/UNI
# /data4/embedding/TCGA-BRCA/FMBC
# remove /data4/embedding/TCGA-BRCA/FMBC
# /data4/embedding/TCGA-BRCA/CHIEF
# /data4/embedding/TCGA-BRCA/Virchow
# /data4/embedding/TCGA-BRCA/Gigapath_tile
# /data4/embedding/TCGA-BRCA/Gigapath
# /data4/embedding/TCGA-BRCA/TITAN
# /data4/embedding/private_chunk_9/FMBC
# remove /data4/embedding/private_chunk_9/FMBC
# /data4/embedding/temp/embedding
# /data4/embedding/GTEX_Breast/CONCH
# /data4/embedding/GTEX_Breast/UNI
# /data4/embedding/GTEX_Breast/FMBC
# remove /data4/embedding/GTEX_Breast/FMBC
# /data4/embedding/GTEX_Breast/CHIEF
# /data4/embedding/GTEX_Breast/Virchow
# /data4/embedding/GTEX_Breast/Gigapath_tile
# /data4/embedding/GTEX_Breast/Gigapath
# /data4/embedding/GTEX_Breast/TITAN
# /data4/embedding/BCNB/CONCH
# /data4/embedding/BCNB/UNI
# /data4/embedding/BCNB/FMBC
# remove /data4/embedding/BCNB/FMBC
# /data4/embedding/BCNB/CHIEF
# /data4/embedding/BCNB/Virchow
# /data4/embedding/BCNB/Gigapath_tile
# /data4/embedding/BCNB/Gigapath
# /data4/embedding/BCNB/TITAN
# /data4/embedding/ACROBAT/CONCH
# /data4/embedding/ACROBAT/UNI
# /data4/embedding/ACROBAT/FMBC
# remove /data4/embedding/ACROBAT/FMBC
# /data4/embedding/ACROBAT/CHIEF
# /data4/embedding/ACROBAT/Virchow
# /data4/embedding/ACROBAT/Gigapath_tile
# /data4/embedding/ACROBAT/Gigapath
# /data4/embedding/ACROBAT/TITAN
# /data4/embedding/BACH/CONCH
# /data4/embedding/BACH/UNI
# /data4/embedding/BACH/CHIEF
# /data4/embedding/BACH/Virchow
# /data4/embedding/BACH/Gigapath_tile
# /data4/embedding/BACH/Gigapath
# /data4/embedding/BACH/TITAN
# /data4/embedding/CPTAC-BREAST-all/CONCH
# /data4/embedding/CPTAC-BREAST-all/UNI
# /data4/embedding/CPTAC-BREAST-all/FMBC
# remove /data4/embedding/CPTAC-BREAST-all/FMBC
# /data4/embedding/CPTAC-BREAST-all/CHIEF
# /data4/embedding/CPTAC-BREAST-all/Virchow
# /data4/embedding/CPTAC-BREAST-all/Gigapath_tile
# /data4/embedding/CPTAC-BREAST-all/Gigapath
# /data4/embedding/CPTAC-BREAST-all/TITAN
# /data4/embedding/TIGER/CONCH
# /data4/embedding/TIGER/UNI
# /data4/embedding/TIGER/FMBC
# remove /data4/embedding/TIGER/FMBC
# /data4/embedding/TIGER/CHIEF
# /data4/embedding/TIGER/Virchow
# /data4/embedding/TIGER/Gigapath_tile
# /data4/embedding/TIGER/Gigapath
# /data4/embedding/TIGER/TITAN
# /data4/embedding/private_chunk_5/FMBC
# remove /data4/embedding/private_chunk_5/FMBC
# /data4/embedding/private_chunk_8/FMBC
# remove /data4/embedding/private_chunk_8/FMBC
# /data4/embedding/HyReCo/CONCH
# /data4/embedding/HyReCo/UNI
# /data4/embedding/HyReCo/FMBC
# remove /data4/embedding/HyReCo/FMBC
# /data4/embedding/HyReCo/CHIEF
# /data4/embedding/HyReCo/Virchow
# /data4/embedding/HyReCo/Gigapath_tile
# /data4/embedding/HyReCo/Gigapath
# /data4/embedding/HyReCo/TITAN
# /data4/embedding/private_chunk_2/FMBC
# remove /data4/embedding/private_chunk_2/FMBC
# /data4/embedding/Multi-omic/CONCH
# /data4/embedding/Multi-omic/UNI
# /data4/embedding/Multi-omic/FMBC
# remove /data4/embedding/Multi-omic/FMBC
# /data4/embedding/Multi-omic/CHIEF
# /data4/embedding/Multi-omic/Virchow
# /data4/embedding/Multi-omic/Gigapath_tile
# /data4/embedding/Multi-omic/Gigapath
# /data4/embedding/Multi-omic/TITAN
# /data4/embedding/DORID/CONCH
# /data4/embedding/DORID/UNI
# /data4/embedding/DORID/Virchow
# /data4/embedding/DORID/Gigapath_tile
# /data4/embedding/DORID/Gigapath
# /data4/embedding/DORID/TITAN
# /data4/embedding/private_chunk_10/FMBC
# remove /data4/embedding/private_chunk_10/FMBC
# /data4/embedding/CAMELYON17/CONCH
# /data4/embedding/CAMELYON17/UNI
# /data4/embedding/CAMELYON17/FMBC
# remove /data4/embedding/CAMELYON17/FMBC
# /data4/embedding/CAMELYON17/CHIEF
# /data4/embedding/CAMELYON17/Virchow
# /data4/embedding/CAMELYON17/Gigapath_tile
# /data4/embedding/CAMELYON17/Gigapath
# /data4/embedding/CAMELYON17/TITAN
# /data4/embedding/private_chunk_1/FMBC
# remove /data4/embedding/private_chunk_1/FMBC
# /data4/embedding/private_chunk_6/FMBC
# remove /data4/embedding/private_chunk_6/FMBC
# /data4/embedding/AIDPATH/CONCH
# /data4/embedding/AIDPATH/UNI
# /data4/embedding/AIDPATH/FMBC
# remove /data4/embedding/AIDPATH/FMBC
# /data4/embedding/AIDPATH/CHIEF
# /data4/embedding/AIDPATH/Virchow
# /data4/embedding/AIDPATH/Gigapath_tile
# /data4/embedding/AIDPATH/Gigapath
# /data4/embedding/AIDPATH/TITAN
# /data4/embedding/SLN-Breast/CONCH
# /data4/embedding/SLN-Breast/UNI
# /data4/embedding/SLN-Breast/FMBC
# remove /data4/embedding/SLN-Breast/FMBC
# /data4/embedding/SLN-Breast/CHIEF
# /data4/embedding/SLN-Breast/Virchow
# /data4/embedding/SLN-Breast/Gigapath_tile
# /data4/embedding/SLN-Breast/Gigapath
# /data4/embedding/SLN-Breast/TITAN
# /data4/embedding/CMB-BRCA/CONCH
# /data4/embedding/CMB-BRCA/UNI
# /data4/embedding/CMB-BRCA/FMBC
# remove /data4/embedding/CMB-BRCA/FMBC
# /data4/embedding/CMB-BRCA/CHIEF
# /data4/embedding/CMB-BRCA/Virchow
# /data4/embedding/CMB-BRCA/Gigapath_tile
# /data4/embedding/CMB-BRCA/Gigapath
# /data4/embedding/CMB-BRCA/TITAN
# /data4/embedding/TNBC/CONCH
# /data4/embedding/TNBC/UNI
# /data4/embedding/TNBC/Virchow
# /data4/embedding/TNBC/Gigapath_tile
# /data4/embedding/TNBC/Gigapath
# /data4/embedding/TNBC/TITAN
