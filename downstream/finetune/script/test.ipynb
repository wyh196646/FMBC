# %%
import os
import pandas as pd
import yaml

#生成到test dir里面，不要破坏已经处理好的config，有些config去除了太少的类别，这样一生成
#全都覆盖掉了，这样就不对了
config_file_path = "/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/biomarker/BCNB_ER.yaml"
csv_dir = "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker"
output_yaml_dir = "/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir"
os.makedirs(output_yaml_dir, exist_ok=True)
with open(config_file_path, "r") as f:
    config_template = yaml.safe_load(f)

# 遍历目录下的所有 CSV 文件
for file in os.listdir(csv_dir):
    if file.endswith(".csv"):
        csv_path = os.path.join(csv_dir, file)

        # 读取 CSV 文件
        df = pd.read_csv(csv_path)
        #print(df['label'].unique())
        # 提取所有列名
        column_names = df.columns.tolist()

        try:
            possible_label_cols = [col for col in column_names if "label" in col.lower()]
            task_col = possible_label_cols[0] if possible_label_cols else "label"  # 默认选择第一个匹配的 label 列
        
                # 识别 sample_col (一般是 slide_id)
            sample_col = "slide_id" if "slide_id" in column_names else column_names[0]
            unique_label = df[task_col].unique().tolist()
            label_dict = {int(label) if isinstance(label, (int, float, str)) and str(label).isdigit() else label: i for i, label in enumerate(unique_label)}
            label_dict = {label: i for i, label in enumerate(unique_label)}
            # 生成 YAML 配置内容
            config_output = {
                "name": file.split(".csv")[0].upper(),  # 使用 CSV 文件名（大写）作为数据集名称
                #"task_col": task_col,
                "setting": config_template["setting"],  # 继承 YAML 模板的 task_type
                "add_metrics": config_template['add_metrics'],  # 继承 YAML 模板的 metrics
                "label_dict": label_dict ,  # 继承 YAML 模板的 label_dict
                #"sample_col": sample_col,  # 设定 sample_col
                "max_tiles": config_template["max_tiles"],  # 继承 YAML 模板的 max_tiles
                "shuffle_tiles": config_template["shuffle_tiles"],  # 继承 YAML 模板的 shuffle_tils
            }

            # 生成 YAML 文件存储路径
            output_yaml_path = os.path.join(output_yaml_dir, f"{file.split('.csv')[0].upper()}.yaml")

            # 写入 YAML 文件
            with open(output_yaml_path, "w") as f:
                yaml.dump(config_output, f, default_flow_style=False)

            print(f"✅ 生成 YAML: {output_yaml_path}")
        except Exception as e:
            print(f"❌ 生成 YAML 失败: {file}，错误信息: {e}")

print("🎉 所有 CSV 文件的 YAML 配置已生成完毕！")
# Out:
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/TCGA-BRCA_MOLECULAR_SUBTYPING.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_PCR.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_PD-L1-TUMOR.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_CD8-PERITUMORAL.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_PD-L1-STROMA.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_PR.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_CD163-PERITUMORAL.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BCNB_HER2.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/POST-NAT-BRCA-ANTIHER2.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/AIDPATH_KI67PRED.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/POST-NAT-BRCA-ER.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BCNB_ER.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/AIDPATH_CERB2.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_CD163-INTRATUMORAL.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BCNB_PR.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_CD8-INTRATUMORAL.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/TCGA-BRCA_TP53.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/AIDPATH_RESTR.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/TCGA-BRCA_HRD.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/CPTAC_AJCC8SUBTYPE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_ER.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/POST-NAT-BRCA-PR.yaml
# 🎉 所有 CSV 文件的 YAML 配置已生成完毕！

# %%
import yaml
a_path = '/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BRACS_COARSE.yaml'
b_path = '/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/BRACS_COARSE.yaml'
with open(a_path, "r") as f:
    a= yaml.safe_load(f)
with open(b_path, "r") as f:
    b= yaml.safe_load(f)

# %%
import os
import json

# CSV 文件目录
csv_dir = "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker"

# 获取所有 CSV 文件名（去掉扩展名）
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# 生成 config 字典
config = {}

for file in csv_files:
    key = file.replace('.csv', '')  # 作为 key
    embedding_dir = f"/data4/embedding/{key}"  # 生成 embedding_dir
    task_cfg = f"task_configs/{key}.yaml"  # 生成 task_cfg
    
    config[key] = {
        "embedding_dir": embedding_dir,
        "csv_dir": csv_dir,
        "task_cfg": task_cfg
    }

# 格式化 JSON 并输出
config_json = json.dumps(config, indent=4, ensure_ascii=False)
print(config_json)
# Out:
# {
#     "TCGA-BRCA_MOLECULAR_SUBTYPING": {
#         "embedding_dir": "/data4/embedding/TCGA-BRCA_MOLECULAR_SUBTYPING",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/TCGA-BRCA_MOLECULAR_SUBTYPING.yaml"
#     },
#     "IMPRESS_PCR": {
#         "embedding_dir": "/data4/embedding/IMPRESS_PCR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_PCR.yaml"
#     },
#     "IMPRESS_PD-L1-TUMOR": {
#         "embedding_dir": "/data4/embedding/IMPRESS_PD-L1-TUMOR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_PD-L1-TUMOR.yaml"
#     },
#     "IMPRESS_CD8-PERITUMORAL": {
#         "embedding_dir": "/data4/embedding/IMPRESS_CD8-PERITUMORAL",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_CD8-PERITUMORAL.yaml"
#     },
#     "IMPRESS_PD-L1-STROMA": {
#         "embedding_dir": "/data4/embedding/IMPRESS_PD-L1-STROMA",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_PD-L1-STROMA.yaml"
#     },
#     "IMPRESS_PR": {
#         "embedding_dir": "/data4/embedding/IMPRESS_PR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_PR.yaml"
#     },
#     "IMPRESS_CD163-PERITUMORAL": {
#         "embedding_dir": "/data4/embedding/IMPRESS_CD163-PERITUMORAL",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_CD163-PERITUMORAL.yaml"
#     },
#     "BCNB_HER2": {
#         "embedding_dir": "/data4/embedding/BCNB_HER2",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/BCNB_HER2.yaml"
#     },
#     "AIDPATH_KI67PRED": {
#         "embedding_dir": "/data4/embedding/AIDPATH_KI67PRED",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/AIDPATH_KI67PRED.yaml"
#     },
#     "POST-NAT-PR": {
#         "embedding_dir": "/data4/embedding/POST-NAT-PR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/POST-NAT-PR.yaml"
#     },
#     "BCNB_ER": {
#         "embedding_dir": "/data4/embedding/BCNB_ER",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/BCNB_ER.yaml"
#     },
#     "AIDPATH_CERB2": {
#         "embedding_dir": "/data4/embedding/AIDPATH_CERB2",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/AIDPATH_CERB2.yaml"
#     },
#     "IMPRESS_CD163-INTRATUMORAL": {
#         "embedding_dir": "/data4/embedding/IMPRESS_CD163-INTRATUMORAL",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_CD163-INTRATUMORAL.yaml"
#     },
#     "BCNB_PR": {
#         "embedding_dir": "/data4/embedding/BCNB_PR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/BCNB_PR.yaml"
#     },
#     "POST-NAT-ER": {
#         "embedding_dir": "/data4/embedding/POST-NAT-ER",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/POST-NAT-ER.yaml"
#     },
#     "IMPRESS_CD8-INTRATUMORAL": {
#         "embedding_dir": "/data4/embedding/IMPRESS_CD8-INTRATUMORAL",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_CD8-INTRATUMORAL.yaml"
#     },
#     "TCGA-BRCA_TP53": {
#         "embedding_dir": "/data4/embedding/TCGA-BRCA_TP53",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/TCGA-BRCA_TP53.yaml"
#     },
#     "AIDPATH_RESTR": {
#         "embedding_dir": "/data4/embedding/AIDPATH_RESTR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/AIDPATH_RESTR.yaml"
#     },
#     "TCGA-BRCA_HRD": {
#         "embedding_dir": "/data4/embedding/TCGA-BRCA_HRD",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/TCGA-BRCA_HRD.yaml"
#     },
#     "POST-NAT-ANTIHER2": {
#         "embedding_dir": "/data4/embedding/POST-NAT-ANTIHER2",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/POST-NAT-ANTIHER2.yaml"
#     },
#     "CPTAC_AJCC8SUBTYPE": {
#         "embedding_dir": "/data4/embedding/CPTAC_AJCC8SUBTYPE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/CPTAC_AJCC8SUBTYPE.yaml"
#     },
#     "IMPRESS_ER": {
#         "embedding_dir": "/data4/embedding/IMPRESS_ER",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/biomarker",
#         "task_cfg": "task_configs/IMPRESS_ER.yaml"
#     }
# }
