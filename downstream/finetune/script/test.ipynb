# %%
import os
import pandas as pd
import yaml


config_file_path = "/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/BCNB_ER.yaml"
csv_dir = "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype"
output_yaml_dir = "/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir"
os.makedirs(output_yaml_dir, exist_ok=True)
with open(config_file_path, "r") as f:
    config_template = yaml.safe_load(f)

# 遍历目录下的所有 CSV 文件
for file in os.listdir(csv_dir):
    if file.endswith(".csv"):
        csv_path = os.path.join(csv_dir, file)

        # 读取 CSV 文件
        df = pd.read_csv(csv_path)
        #print(df['label'].unique())
        # 提取所有列名
        column_names = df.columns.tolist()

        try:
            possible_label_cols = [col for col in column_names if "label" in col.lower()]
            task_col = possible_label_cols[0] if possible_label_cols else "label"  # 默认选择第一个匹配的 label 列
        
                # 识别 sample_col (一般是 slide_id)
            sample_col = "slide_id" if "slide_id" in column_names else column_names[0]
            unique_label = df[task_col].unique().tolist()
            label_dict = {int(label) if isinstance(label, (int, float, str)) and str(label).isdigit() else label: i for i, label in enumerate(unique_label)}
            label_dict = {label: i for i, label in enumerate(unique_label)}
            # 生成 YAML 配置内容
            config_output = {
                "name": file.split(".csv")[0].upper(),  # 使用 CSV 文件名（大写）作为数据集名称
                #"task_col": task_col,
                "setting": config_template["setting"],  # 继承 YAML 模板的 task_type
                "add_metrics": config_template['add_metrics'],  # 继承 YAML 模板的 metrics
                "label_dict": label_dict ,  # 继承 YAML 模板的 label_dict
                #"sample_col": sample_col,  # 设定 sample_col
                "max_tiles": config_template["max_tiles"],  # 继承 YAML 模板的 max_tiles
                "shuffle_tiles": config_template["shuffle_tiles"],  # 继承 YAML 模板的 shuffle_tils
            }

            # 生成 YAML 文件存储路径
            output_yaml_path = os.path.join(output_yaml_dir, f"{file.split('.csv')[0].upper()}.yaml")

            # 写入 YAML 文件
            with open(output_yaml_path, "w") as f:
                yaml.dump(config_output, f, default_flow_style=False)

            print(f"✅ 生成 YAML: {output_yaml_path}")
        except Exception as e:
            print(f"❌ 生成 YAML 失败: {file}，错误信息: {e}")

print("🎉 所有 CSV 文件的 YAML 配置已生成完毕！")
# Out:
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/TCGA-BRCA-SUBTYPE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/CAMELYON16_TEST_CANCER.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/DORID_2.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/TCGA-BRCA_T.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BRACS_COARSE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/AHSL-NON-IDC-GRADE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/CAMELYON16_TEST_IDC.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BCNB_TUMOR.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BCNB_ALN.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/AIDPATH_IDC.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/CAMELYON17_STAGE_4SUBTYPING.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/IMPRESS_RESIDUAL-TUMOR.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/AHSL-GRADE-3.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BRACS_FINE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/AHSL-GRADE-1.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BACH_TUMOR.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/SLNBREAST_SUBTYPE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/TCGA-BRCA_STAGE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/POST-NAT-3TYPE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/TCGA-BRCA_M.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/DORID_6.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/CPTAC_IDC.yaml
# ❌ 生成 YAML 失败: TUPAC_TUMOR_SCORE.csv，错误信息: 'label'
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/AIDPATH_GRADE.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/TCGA-BRCA_N.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/POST-NAT-HERIHC.yaml
# ✅ 生成 YAML: /home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/CAMELYON17_STAGE.yaml
# 🎉 所有 CSV 文件的 YAML 配置已生成完毕！

# %%
import yaml
a_path = '/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/test_dir/BRACS_COARSE.yaml'
b_path = '/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/BRACS_COARSE.yaml'
with open(a_path, "r") as f:
    a= yaml.safe_load(f)
with open(b_path, "r") as f:
    b= yaml.safe_load(f)

# %%
a
# Out:
# {'add_metrics': ['qwk'],
#  'label_dict': {0: 0, 1: 2, 2: 1},
#  'max_tiles': 4000,
#  'name': 'BRACS_COARSE',
#  'setting': 'multi_class',
#  'shuffle_tiles': True}

# %%
b
# Out:
# {'name': 'BRACS_COARSE',
#  'setting': 'multi_class',
#  'label_dict': {0: 0, 1: 1, 2: 2},
#  'max_tiles': 4000,
#  'shuffle_tiles': True,
#  'add_metrics': ['qwk']}

# %%
import os
import json

# CSV 文件目录
csv_dir = "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype"

# 获取所有 CSV 文件名（去掉扩展名）
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# 生成 config 字典
config = {}

for file in csv_files:
    key = file.replace('.csv', '')  # 作为 key
    embedding_dir = f"/data4/embedding/{key}"  # 生成 embedding_dir
    task_cfg = f"task_configs/{key}.yaml"  # 生成 task_cfg
    
    config[key] = {
        "embedding_dir": embedding_dir,
        "csv_dir": csv_dir,
        "task_cfg": task_cfg
    }

# 格式化 JSON 并输出
config_json = json.dumps(config, indent=4, ensure_ascii=False)
print(config_json)
# Out:
# {
#     "TCGA-BRCA-SUBTYPE": {
#         "embedding_dir": "/data4/embedding/TCGA-BRCA-SUBTYPE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/TCGA-BRCA-SUBTYPE.yaml"
#     },
#     "CAMELYON16_TEST_CANCER": {
#         "embedding_dir": "/data4/embedding/CAMELYON16_TEST_CANCER",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/CAMELYON16_TEST_CANCER.yaml"
#     },
#     "DORID_2": {
#         "embedding_dir": "/data4/embedding/DORID_2",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/DORID_2.yaml"
#     },
#     "TCGA-BRCA_T": {
#         "embedding_dir": "/data4/embedding/TCGA-BRCA_T",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/TCGA-BRCA_T.yaml"
#     },
#     "BRACS_COARSE": {
#         "embedding_dir": "/data4/embedding/BRACS_COARSE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/BRACS_COARSE.yaml"
#     },
#     "AHSL-NON-IDC-GRADE": {
#         "embedding_dir": "/data4/embedding/AHSL-NON-IDC-GRADE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/AHSL-NON-IDC-GRADE.yaml"
#     },
#     "CAMELYON16_TEST_IDC": {
#         "embedding_dir": "/data4/embedding/CAMELYON16_TEST_IDC",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/CAMELYON16_TEST_IDC.yaml"
#     },
#     "BCNB_TUMOR": {
#         "embedding_dir": "/data4/embedding/BCNB_TUMOR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/BCNB_TUMOR.yaml"
#     },
#     "BCNB_ALN": {
#         "embedding_dir": "/data4/embedding/BCNB_ALN",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/BCNB_ALN.yaml"
#     },
#     "AIDPATH_IDC": {
#         "embedding_dir": "/data4/embedding/AIDPATH_IDC",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/AIDPATH_IDC.yaml"
#     },
#     "CAMELYON17_STAGE_4SUBTYPING": {
#         "embedding_dir": "/data4/embedding/CAMELYON17_STAGE_4SUBTYPING",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/CAMELYON17_STAGE_4SUBTYPING.yaml"
#     },
#     "IMPRESS_RESIDUAL-TUMOR": {
#         "embedding_dir": "/data4/embedding/IMPRESS_RESIDUAL-TUMOR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/IMPRESS_RESIDUAL-TUMOR.yaml"
#     },
#     "AHSL-GRADE-3": {
#         "embedding_dir": "/data4/embedding/AHSL-GRADE-3",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/AHSL-GRADE-3.yaml"
#     },
#     "BRACS_FINE": {
#         "embedding_dir": "/data4/embedding/BRACS_FINE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/BRACS_FINE.yaml"
#     },
#     "AHSL-GRADE-1": {
#         "embedding_dir": "/data4/embedding/AHSL-GRADE-1",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/AHSL-GRADE-1.yaml"
#     },
#     "BACH_TUMOR": {
#         "embedding_dir": "/data4/embedding/BACH_TUMOR",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/BACH_TUMOR.yaml"
#     },
#     "SLNBREAST_SUBTYPE": {
#         "embedding_dir": "/data4/embedding/SLNBREAST_SUBTYPE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/SLNBREAST_SUBTYPE.yaml"
#     },
#     "TCGA-BRCA_STAGE": {
#         "embedding_dir": "/data4/embedding/TCGA-BRCA_STAGE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/TCGA-BRCA_STAGE.yaml"
#     },
#     "POST-NAT-3TYPE": {
#         "embedding_dir": "/data4/embedding/POST-NAT-3TYPE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/POST-NAT-3TYPE.yaml"
#     },
#     "TCGA-BRCA_M": {
#         "embedding_dir": "/data4/embedding/TCGA-BRCA_M",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/TCGA-BRCA_M.yaml"
#     },
#     "DORID_6": {
#         "embedding_dir": "/data4/embedding/DORID_6",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/DORID_6.yaml"
#     },
#     "CPTAC_IDC": {
#         "embedding_dir": "/data4/embedding/CPTAC_IDC",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/CPTAC_IDC.yaml"
#     },
#     "TUPAC_TUMOR_SCORE": {
#         "embedding_dir": "/data4/embedding/TUPAC_TUMOR_SCORE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/TUPAC_TUMOR_SCORE.yaml"
#     },
#     "AIDPATH_GRADE": {
#         "embedding_dir": "/data4/embedding/AIDPATH_GRADE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/AIDPATH_GRADE.yaml"
#     },
#     "TCGA-BRCA_N": {
#         "embedding_dir": "/data4/embedding/TCGA-BRCA_N",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/TCGA-BRCA_N.yaml"
#     },
#     "POST-NAT-HERIHC": {
#         "embedding_dir": "/data4/embedding/POST-NAT-HERIHC",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/POST-NAT-HERIHC.yaml"
#     },
#     "CAMELYON17_STAGE": {
#         "embedding_dir": "/data4/embedding/CAMELYON17_STAGE",
#         "csv_dir": "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/subtype",
#         "task_cfg": "task_configs/CAMELYON17_STAGE.yaml"
#     }
# }
