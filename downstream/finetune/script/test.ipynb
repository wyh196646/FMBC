# %%
import h5py
import os
def read_assets_from_h5( h5_path: str) -> tuple:
    '''Read the assets from the h5 file'''
    assets = {}
    attrs = {}
    with h5py.File(h5_path, 'r') as f:
        for key in f.keys():
            assets[key] = f[key][:]
            if f[key].attrs is not None:
                attrs[key] = dict(f[key].attrs)
    return assets, attrs

# test_case = '/data4/embedding/TCGA-BRCA/TITAN/TCGA-BH-A0C7-01.h5'
file_dir  = '/data4/embedding/TCGA-BRCA/TITAN'
for case in os.listdir(file_dir):
    assets, attrs = read_assets_from_h5(os.path.join(file_dir, case))
    print(assets['features'].shape)
# Out:
# (1, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (1, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (1, 768)
# (1, 768)
# (1, 768)
# (1, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (1, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# (5, 768)
# (1, 768)
# (1, 768)
# (1, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (5, 768)
# (1, 768)
# ...

# %%
import os
import pandas as pd
import yaml

# 配置文件路径（请修改为你的 config.yaml 位置）
config_file_path = "/home/yuhaowang/project/FMBC/downstream/finetune/task_configs/BCNB_ALN.yaml"

# CSV 文件所在的目录（请修改为你的 CSV 目录）
csv_dir = "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/test"

# YAML 文件输出目录（请修改为你的目标路径）
output_yaml_dir = "/home/yuhaowang/project/FMBC/downstream/finetune/dataset_csv/test"

# 确保输出目录存在
os.makedirs(output_yaml_dir, exist_ok=True)

# 读取 YAML 配置模板
with open(config_file_path, "r") as f:
    config_template = yaml.safe_load(f)

# 遍历目录下的所有 CSV 文件
for file in os.listdir(csv_dir):
    if file.endswith(".csv"):
        csv_path = os.path.join(csv_dir, file)

        # 读取 CSV 文件
        df = pd.read_csv(csv_path)

        # 提取所有列名
        column_names = df.columns.tolist()

        # 识别可能的 label 列
        possible_label_cols = [col for col in column_names if "label" in col.lower()]
        task_col = possible_label_cols[0] if possible_label_cols else "label"  # 默认选择第一个匹配的 label 列

        # 识别 sample_col (一般是 slide_id)
        sample_col = "slide_id" if "slide_id" in column_names else column_names[0]

        # 生成 YAML 配置内容
        config_output = {
            "datasets": [file.split(".csv")[0].upper()],  # 使用 CSV 文件名（大写）作为数据集名称
            "task_col": task_col,
            "extra_cols": [col for col in column_names if col not in [sample_col, task_col]],  # 额外的列
            "setting": config_template["setting"],  # 继承 YAML 模板的 task_type
            "metrics": config_template["metrics"],  # 继承 YAML 模板的 metrics
            "label_dict": config_template["label_dict"],  # 继承 YAML 模板的 label_dict
            "sample_col": sample_col,  # 设定 sample_col
            "num_samples": len(df),  # 统计数据集样本数
        }

        # 生成 YAML 文件存储路径
        output_yaml_path = os.path.join(output_yaml_dir, f"{file.split('.csv')[0].upper()}.yaml")

        # 写入 YAML 文件
        with open(output_yaml_path, "w") as f:
            yaml.dump(config_output, f, default_flow_style=False)

        print(f"✅ 生成 YAML: {output_yaml_path}")

print("🎉 所有 CSV 文件的 YAML 配置已生成完毕！")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 45
#      37 sample_col = "slide_id" if "slide_id" in column_names else column_names[0]
#      39 # 生成 YAML 配置内容
#      40 config_output = {
#      41     "datasets": [file.split(".csv")[0].upper()],  # 使用 CSV 文件名（大写）作为数据集名称
#      42     "task_col": task_col,
#      43     "extra_cols": [col for col in column_names if col not in [sample_col, task_col]],  # 额外的列
#      44     "task_type": config_template["setting"],  # 继承 YAML 模板的 task_type
# ---> 45     "metrics": config_template["metrics"],  # 继承 YAML 模板的 metrics
#      46     "label_dict": config_template["label_dict"],  # 继承 YAML 模板的 label_dict
#      47     "sample_col": sample_col,  # 设定 sample_col
#      48     "num_samples": len(df),  # 统计数据集样本数
#      49 }
#      51 # 生成 YAML 文件存储路径
# ...
