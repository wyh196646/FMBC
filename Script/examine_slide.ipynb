# %%
import os
from collections import defaultdict

data_path = '/data4/processed_data'
embedding_path = '/data4/embedding'

def get_total_slides(dataset_path):
    """Get total slides count in the output directory."""
    output_path = os.path.join(dataset_path, 'output')
    return len(os.listdir(output_path)) if os.path.exists(output_path) else 0

def analyze_embeddings():
    dataset_model_counts = defaultdict(int)
    dataset_missing_counts = defaultdict(lambda: defaultdict(int))
    all_models = set()
    
    for dataset in os.listdir(data_path):
        dataset_path = os.path.join(data_path, dataset)
        total_slides = get_total_slides(dataset_path)
        #print(f'{dataset} has {total_slides} slides')
        
        dataset_embedding_path = os.path.join(embedding_path, dataset)
        if not os.path.exists(dataset_embedding_path):
           # print(f'{dataset} has no embedding')
            #print('---------------------------')
            continue
        
        model_slide_counts = {}
        for model in os.listdir(dataset_embedding_path):
            model_path = os.path.join(dataset_embedding_path, model)
            processed_slides = len(os.listdir(model_path))
            model_slide_counts[model] = processed_slides
            all_models.add(model)
            #print(f'{model} has {processed_slides} slides processed')
            missing_slides = total_slides - processed_slides
            dataset_missing_counts[dataset][model] = missing_slides
            dataset_model_counts[dataset] = max(dataset_model_counts[dataset], len(model_slide_counts))
        
        #print('---------------------------')
    
    # Determine the complete set of models that should be present
    max_model_count = max(dataset_model_counts.values(), default=0)
    
    print("Summary of missing slides per dataset/model:")
    for dataset, models in dataset_missing_counts.items():
        print(f'Dataset: {dataset}')
        missing_models = all_models - set(models.keys())
        for model in all_models:
            if model not in models:
                print(f'  Missing Model: {model} (0 slides processed)')
            else:
                print(f'  Model: {model}, Missing: {models[model]} slides')
        
        #print(f'  Missing {len(missing_models)} models to match max ({max_model_count})')
        print('---------------------------')

if __name__ == "__main__":
    analyze_embeddings()
# Out:
# Summary of missing slides per dataset/model:
# Dataset: private_chunk_9
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2695 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: TCGA-BRCA
#   Model: FMBC, Missing: 935 slides
#   Model: CONCH, Missing: -2126 slides
#   Model: UNI, Missing: -992 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: -991 slides
#   Model: TITAN, Missing: -1604 slides
#   Model: CHIEF_tile, Missing: -991 slides
#   Model: UNI-2, Missing: 0 slides
#   Model: CHIEF, Missing: -991 slides
#   Model: Gigapath, Missing: -991 slides
#   Missing 1 models to match max (9)
# ---------------------------
# Dataset: CAMELYON17
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 138 slides
#   Model: UNI-2, Missing: 0 slides
#   Model: CHIEF, Missing: 499 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: TIGER
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -153 slides
#   Model: UNI, Missing: -151 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: -151 slides
#   Model: TITAN, Missing: -151 slides
#   Model: CHIEF_tile, Missing: -151 slides
#   Model: UNI-2, Missing: 1 slides
#   Model: CHIEF, Missing: 0 slides
#   Model: Gigapath, Missing: -151 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: private_chunk_2
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2689 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: private_chunk_4
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2676 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: HE-vs-MPM
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: 0 slides
#   Model: UNI, Missing: 2 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 2 slides
#   Model: TITAN, Missing: 2 slides
#   Model: CHIEF_tile, Missing: 2 slides
#   Missing Model: UNI-2 (0 slides processed)
#   Model: CHIEF, Missing: 14 slides
#   Model: Gigapath, Missing: 2 slides
#   Missing 3 models to match max (9)
# ---------------------------
# Dataset: AIDPATH
#   Model: FMBC, Missing: 0 slides
#   Model: CONCH, Missing: -501 slides
#   Model: UNI, Missing: -499 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: -499 slides
#   Model: TITAN, Missing: -499 slides
#   Model: CHIEF_tile, Missing: -499 slides
#   Model: UNI-2, Missing: 17 slides
#   Model: CHIEF, Missing: -500 slides
#   Model: Gigapath, Missing: -499 slides
#   Missing 1 models to match max (9)
# ---------------------------
# Dataset: private_chunk_6
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2681 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: Post-NAT-BRCA
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: 0 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: BACH
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: 800 slides
#   Model: UNI, Missing: 802 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 802 slides
#   Model: TITAN, Missing: 833 slides
#   Model: CHIEF_tile, Missing: 802 slides
#   Model: UNI-2, Missing: 803 slides
#   Model: CHIEF, Missing: 802 slides
#   Model: Gigapath, Missing: 802 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: private_chunk_8
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2676 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: CPTAC-BREAST-all
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: 0 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 1 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 58 slides
#   Model: CHIEF, Missing: 653 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: CAMELYON16
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 0 slides
#   Model: CHIEF, Missing: 0 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: private_chunk_5
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2681 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: private_chunk_10
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2680 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: CMB-BRCA
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 5 slides
#   Model: CHIEF, Missing: 0 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: TUPAC
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 0 slides
#   Model: CHIEF, Missing: 0 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: private_chunk_7
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2670 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: SLN-Breast
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 2 slides
#   Model: CHIEF, Missing: 0 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: BRACS
#   Model: FMBC, Missing: 335 slides
#   Model: CONCH, Missing: -3 slides
#   Model: UNI, Missing: -1 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: -1 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 0 slides
#   Model: CHIEF, Missing: 1 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 1 models to match max (9)
# ---------------------------
# Dataset: IMPRESS
#   Model: FMBC, Missing: 0 slides
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 12 slides
#   Model: CHIEF, Missing: 0 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 1 models to match max (9)
# ---------------------------
# Dataset: GTEX_Breast
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 58 slides
#   Model: CHIEF, Missing: 0 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: private_chunk_3
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -2674 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: private_chunk_1
#   Missing Model: FMBC (0 slides processed)
#   Missing Model: CONCH (0 slides processed)
#   Missing Model: UNI (0 slides processed)
#   Missing Model: Virchow (0 slides processed)
#   Missing Model: Gigapath_tile (0 slides processed)
#   Missing Model: TITAN (0 slides processed)
#   Missing Model: CHIEF_tile (0 slides processed)
#   Model: UNI-2, Missing: -513 slides
#   Missing Model: CHIEF (0 slides processed)
#   Missing Model: Gigapath (0 slides processed)
#   Missing 9 models to match max (9)
# ---------------------------
# Dataset: BreakHis
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Missing Model: UNI-2 (0 slides processed)
#   Model: CHIEF, Missing: 0 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 3 models to match max (9)
# ---------------------------
# Dataset: ACROBAT
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -2 slides
#   Model: UNI, Missing: 0 slides
#   Model: Virchow, Missing: 0 slides
#   Model: Gigapath_tile, Missing: 0 slides
#   Model: TITAN, Missing: 0 slides
#   Model: CHIEF_tile, Missing: 0 slides
#   Model: UNI-2, Missing: 272 slides
#   Model: CHIEF, Missing: 4211 slides
#   Model: Gigapath, Missing: 0 slides
#   Missing 1 models to match max (9)
# ---------------------------
# Dataset: HyReCo
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: 0 slides
#   Model: UNI, Missing: 2 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 2 slides
#   Model: TITAN, Missing: 2 slides
#   Model: CHIEF_tile, Missing: 2 slides
#   Model: UNI-2, Missing: 7 slides
#   Model: CHIEF, Missing: 35 slides
#   Model: Gigapath, Missing: 2 slides
#   Missing 2 models to match max (9)
# ---------------------------
# Dataset: BCNB
#   Model: FMBC, Missing: 0 slides
#   Model: CONCH, Missing: -1060 slides
#   Model: UNI, Missing: -1058 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: -1058 slides
#   Model: TITAN, Missing: -1058 slides
#   Model: CHIEF_tile, Missing: -1058 slides
#   Model: UNI-2, Missing: 37 slides
#   Model: CHIEF, Missing: -1058 slides
#   Model: Gigapath, Missing: -1058 slides
#   Missing 1 models to match max (9)
# ---------------------------
# Dataset: HIST2ST
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: 0 slides
#   Model: UNI, Missing: 2 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: 2 slides
#   Model: TITAN, Missing: 2 slides
#   Model: CHIEF_tile, Missing: 2 slides
#   Model: UNI-2, Missing: 17 slides
#   Missing Model: CHIEF (0 slides processed)
#   Model: Gigapath, Missing: 2 slides
#   Missing 3 models to match max (9)
# ---------------------------
# Dataset: Multi-omic
#   Missing Model: FMBC (0 slides processed)
#   Model: CONCH, Missing: -205 slides
#   Model: UNI, Missing: -203 slides
#   Missing Model: Virchow (0 slides processed)
#   Model: Gigapath_tile, Missing: -203 slides
#   Model: TITAN, Missing: -203 slides
#   Model: CHIEF_tile, Missing: -203 slides
#   Model: UNI-2, Missing: 22 slides
#   Model: CHIEF, Missing: -203 slides
#   Model: Gigapath, Missing: -203 slides
#   Missing 2 models to match max (9)
# ---------------------------
